# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
# mimic like browser as robot.txt not allow access to bots
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/137.0.0.0 Safari/537.36"
    ),
    
    "Accept": (
        "text/html,application/xhtml+xml,"
        "application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8"
    ),
    
    "Accept-Language": "en-US,en;q=0.9",
    
    "Accept-Encoding": "gzip, deflate, br",
    
    "Connection": "keep-alive",
    
    "Upgrade-Insecure-Requests": "1",
    
    "Referer": "https://www.google.com/",
    
    "DNT": "1"
}
webpage=requests.get("https://www.ambitionbox.com/list-of-companies?page=1",headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')
company_name=soup.find_all('h2')
for i in company_name:
    print(i.text.strip())
# Out:
# Companies in India
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# HCLTech
# ICICI Bank
# Tech Mahindra
# Genpact
# TP
# Jio
# Axis Bank
# Concentrix Corporation
# Amazon
# Reliance Retail
# iEnergizer
# LTIMindtree
# HDB Financial Services
# Popular Collections by Industries
# Popular Collections by Cities
# Popular Collections by Roles

# %%
soup=BeautifulSoup(webpage,'lxml')
ratings=soup.find_all('div',class_='rating_text')
for i in ratings:
    print(i.text.strip())
# Out:
# 3.3
# 3.7
# 3.6
# 3.7
# 3.6
# 3.8
# 3.5
# 3.4
# 3.9
# 3.3
# 3.6
# 3.9
# 4.4
# 3.6
# 3.6
# 3.9
# 3.9
# 4.6
# 3.6
# 3.9

# %%
soup=BeautifulSoup(webpage,'lxml')
h2=soup.find_all('span',class_='companyCardWrapper__ActionCount')
for i in h2:
    print(i.text.strip())
# Out:
# 1.2L
# 10.2L
# 11.4k
# 4k
# 10.9k
# 93
# 74.4k
# 7.1L
# 9.4k
# 25.6k
# 6.8k
# 49
# 65.8k
# 4.9L
# 6.9k
# 333
# 4.8k
# 114
# 62.1k
# 6.1L
# 6.5k
# 773
# 5.6k
# 102
# 54.1k
# 4.9L
# 5.6k
# 2.2k
# 3.8k
# 44
# 53.2k
# 1.5L
# 3.1k
# 280
# 3.4k
# 92
# 49.4k
# 5.3L
# 8.5k
# 2.8k
# 4.9k
# 120
# 46.6k
# 3.9L
# 4.6k
# 289
# 3.9k
# 71
# 46.4k
# 1.5L
# 3k
# 7
# 3.8k
# 73
# 43.8k
# 2.9L
# 4.6k
# 632
# 3.5k
# 79
# 42.9k
# 2.4L
# 4k
# 577
# 3.6k
# 67
# 39.1k
# 99.8k
# 2.3k
# 1.6k
# 1.9k
# 38
# 33.9k
# 61.9k
# 4.5k
# --
# 2.6k
# 93
# 33.7k
# 1L
# 2k
# 256
# 2.2k
# 121
# 32.6k
# 1.3L
# 2k
# 18
# 3.2k
# 67
# 31.8k
# 1.6L
# 6k
# 73
# 3.7k
# 95
# 27.6k
# 74.5k
# 2k
# 95
# 1.9k
# 151
# 27.3k
# 24.9k
# 1.6k
# 84
# 575
# 29
# 26.8k
# 2L
# 3.5k
# 523
# 825
# 34
# 26k
# 49.3k
# 1.1k
# 5
# 1.5k
# 73

# %%
soup=BeautifulSoup(webpage,'lxml')
h2=soup.find_all('div',class_='col-left')
company_name=[]
reviews=[]
ratings=[]
c_type=[]
hq=[]
# fetching big container then iterating throgh it in order to get data of all cards in a page
for i in h2:
    names=i.find_all('h2')
    for name in names:
        company_name.append(name.text.strip())
        
    all_reviews=i.find_all('span',class_='companyCardWrapper__companyRatingCount')
    for review in all_reviews:
        reviews.append(review.text.strip())
    
    all_ratings=i.find_all('div',class_='rating_text')
    for rating in all_ratings:
        ratings.append(rating.text.strip())
    
    all_c_type=i.find_all('span',class_='companyCardWrapper__interLinking')
    for c in all_c_type:
        c_type.append(c.text.strip().split('|')[0].strip())
        hq.append(c.text.strip().split('|')[1].strip().split(" ")[0])
    
# to create data frame we pass a dictionary
d={'Name':company_name,'Reviews':reviews,"Ratings":ratings,"Company_type":c_type,"HQ":hq}

# %%
# data frame for page 1 created
df=pd.DataFrame(d)
df
# Out:
#                       Name  Reviews Ratings              Company_type  \
# 0                      TCS   (1.2L)     3.3  IT Services & Consulting
# 1                Accenture  (74.4k)     3.7  IT Services & Consulting
# 2                    Wipro  (65.8k)     3.6  IT Services & Consulting
# 3                Cognizant  (62.1k)     3.7  IT Services & Consulting
# 4                Capgemini  (54.1k)     3.6  IT Services & Consulting
# 5                HDFC Bank  (53.2k)     3.8                   Banking
# 6                  Infosys  (49.4k)     3.5  IT Services & Consulting
# 7                  HCLTech  (46.6k)     3.4  IT Services & Consulting
# 8               ICICI Bank  (46.4k)     3.9                   Banking
# 9            Tech Mahindra  (43.8k)     3.3  IT Services & Consulting
# 10                 Genpact  (42.9k)     3.6           Analytics & KPO
# 11                      TP  (39.1k)     3.9                       BPO
# ...

# %%
# now iterate 49 pages to fetch the complete data of companies from diff pages 
c_names=[]
c_reviews=[]
c_ratings=[]
c_types=[]
c_hqs=[]
for j in range(1,301):
    # loading diff web page in each itr
    webpage=requests.get(f"https://www.ambitionbox.com/list-of-companies?page={j}",headers=headers).text
    soup=BeautifulSoup(webpage,'lxml')
    # loading the container from each page
    conatiner=soup.find_all('div',class_='col-left')
    for i in conatiner:
        names=i.find_all('h2')
        for name in names:
            c_names.append(name.text.strip())
            
        all_c_reviews=i.find_all('span',class_='companyCardWrapper__companyRatingCount')
        for review in all_c_reviews:
            c_reviews.append(review.text.strip())
        
        all_c_ratings=i.find_all('div',class_='rating_text')
        for rating in all_c_ratings:
            c_ratings.append(rating.text.strip())
        
        all_c_types=i.find_all('span',class_='companyCardWrapper__interLinking')
        for c in all_c_types:
            c_types.append(c.text.strip().split('|')[0].strip())
            
        all_c_hqs=i.find_all('span',class_='companyCardWrapper__interLinking')
        for h in all_c_hqs:
            if(len(h.text.strip().split('|'))>1):
                c_hqs.append(h.text.strip().split('|')[1].strip().split(" ")[0])
            else:
                c_hqs.append('NaN')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\mysel\anaconda3\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File c:\Users\mysel\anaconda3\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
di={'Name':c_names,'Reviews':c_reviews,"Ratings":c_ratings,"Company_type":c_types,"HQ":c_hqs}
print(len(c_names),len(c_reviews),len(c_ratings),len(c_types),len(c_hqs))
# Out:
# 980 980 980 980 980

# %%
# data frame for pages 1-49 created
df=pd.DataFrame(di)
# df.to_csv("company_details.csv")
